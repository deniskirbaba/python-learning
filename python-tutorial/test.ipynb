# %%
a = 50
b = 50

# %%
id(a), id(b)
# Out:
# (140705903689688, 140705903689688)

# %%
c = 10
d = 5*2
id(c), id(d)
# Out:
# (140705903688408, 140705903688408)

# %%
range(10)
# Out:
# range(0, 10)

# %%
a, b, c = (i for i in input().split())
print(a, b, c)
# Out:
# 1 2 3

# %%
(i for i in range(10))
# Out:
# <generator object <genexpr> at 0x000002246F783640>

# %%
def test(i):
    print(id(i))

# %%
a = 10
print(id(a))
test(a)
# Out:
# 140705903688408
# 140705903688408

# %%
a = (10, )
print(id(a))
test(a)
# Out:
# 2355513112128
# 2355513112128

# %%
a = [10, 20]
print(id(a))
test(a)
# Out:
# 2355518806656
# 2355518806656

# %%
a = [1, 2, 3]
a[len(a):]
# Out:
# []
